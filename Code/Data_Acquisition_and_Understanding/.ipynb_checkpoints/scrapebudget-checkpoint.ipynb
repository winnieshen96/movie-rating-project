# %%
import requests
import re
from bs4 import BeautifulSoup
import time
from datetime import datetime
import pandas as pd
import os

# %%
def get_HTML_text(page, url, failList, timeGap, path):
#     kv = {'User-Agent': 'Mozilla/5.0'}
    try:
        time.sleep(timeGap)
        r = requests.get(url, timeout=30)
        r.raise_for_status()
        r.encoding = r.apparent_encoding
        return r.text
    except:
        print(page + " fail." + '\r\n')
        saveFailedMovie(failList, page, path)

# %%
def saveFailedPage(faillist, page, path):
    faillist.append(page)
    filename = os.path.join(path, str('failpageList.txt'))
    f = open(filename, 'wt+')
    f.write(str(page) + '\n')
    f.close()

# %%
def get_budget(html):
    budgets = []
    soup = BeautifulSoup(html, "html.parser")
    table = soup.find('table')
    table_rows = table.find_all('tr')
    for index, tr in enumerate(table_rows):
        if index == 0:
            continue
        else:
            td = tr.find_all('td')
            row = [i.text for i in td]
            if row[1] != 'Unknown':
                try:
                    date = str(datetime.strptime(row[1], '%b %d, %Y').year)
                except:
                    date = None
            else:
                date = None
            name = row[2]
            prod_budget = row[3].replace('\xa0$', '').replace(',', '')
            domestic_gross = row[4].replace('\xa0$', '').replace(',', '')
            worldwide_gross = row[5].replace('\xa0$', '').replace(',', '')
            budget = Budget(name, date, prod_budget, domestic_gross, worldwide_gross)
            budgets.append(budget)
    return budgets

# %%
failList = []
page = '1'
url = 'https://www.the-numbers.com/movie/budgets/all/2401'
html = get_HTML_text(page, url, failList, 1, '')
soup = BeautifulSoup(html, "html.parser")
table = soup.find('table')
table_rows = table.find_all('tr')
for index, tr in enumerate(table_rows):
    if index == 0:
        continue
    else:
        td = tr.find_all('td')
        row = [i.text for i in td]
        if row[1] != 'Unknown':
            date = str(datetime.strptime(row[1], '%b %d, %Y').year)
        else:
            date = None
        name = row[2]
        prod_budget = row[3].replace('\xa0$', '').replace(',', '')
        domestic_gross = row[4].replace('\xa0$', '').replace(',', '')
        worldwide_gross = row[5].replace('\xa0$', '').replace(',', '')
        budget = [name, date, prod_budget, domestic_gross, worldwide_gross]
        print(budget)
# Out:
# ['Belka i Strelka. Zvezdnye sobaki', None, '25000000', '0', '9445081']
# ['Matilda', '2017', '25000000', '0', '9370285']
# ['La véritable histoire du Chat Botté', '2011', '25000000', '0', '8208594']
# ['The Professor and the Madman', '2019', '25000000', '0', '6145843']
# ['Ironclad', '2011', '25000000', '0', '5297411']
# ['Red Sky', '2014', '25000000', '0', '91116']
# ['Waterloo', '1970', '25000000', '0', '0']
# ['The Adventurer: The Curse of the Midas Box', '2014', '25000000', '0', '0']
# ['Reagan', None, '25000000', '0', '0']
# ['Dangerous Liaisons', '2012', '24200000', '17000', '10447579']
# ['Star Trek IV: The Voyage Home', '1986', '24000000', '109713132', '133000000']
# ['Scream 2', '1997', '24000000', '101363301', '172363301']
# ['The Addams Family', '2019', '24000000', '97185807', '200185807']
# ['Old School', '2003', '24000000', '75155000', '86765463']
# ['Rocky Balboa', '2006', '24000000', '70269899', '156229050']
# ['Think Like a Man Too', '2014', '24000000', '65028687', '70027933']
# ['Fences', '2016', '24000000', '57682904', '64282881']
# ['The Whole Nine Yards', '2000', '24000000', '57262492', '85527867']
# ['Footloose', '2011', '24000000', '51802742', '62989834']
# ['Going in Style', '2017', '24000000', '45018541', '78672579']
# ['Point Break', '1991', '24000000', '43218387', '83531958']
# ['The Fisher King', '1991', '24000000', '41798224', '41798224']
# ['I Still Know What You Did Last Summer', '1998', '24000000', '40020622', '40020622']
# ['Hitman', '2007', '24000000', '39687694', '99135571']
# ['Hello, Dolly', '1969', '24000000', '33208099', '33208099']
# ['Return to Me', '2000', '24000000', '32662299', '32662299']
# ['The Men Who Stare at Goats', '2009', '24000000', '32428195', '67348218']
# ['Zack and Miri Make a Porno', '2008', '24000000', '31457946', '36856306']
# ['Double Take', '2001', '24000000', '29823162', '29823162']
# ['Girl, Interrupted', '1999', '24000000', '28871190', '28871190']
# ['Nurse Betty', '2000', '24000000', '25170054', '27732366']
# ['Piranha 3D', '2010', '24000000', '25003155', '83660160']
# ['Faster', '2010', '24000000', '23240020', '35792945']
# ['The Wiz', '1978', '24000000', '22000000', '22000000']
# ['Win a Date with Tad Hamilton!', '2004', '24000000', '16980098', '17589829']
# ['Muppets From Space', '1999', '24000000', '16304786', '16304786']
# ['Ready to Rumble', '2000', '24000000', '12372410', '12372410']
# ['Foxcatcher', '2014', '24000000', '12096300', '19303058']
# ["I Don't Know How She Does It", '2011', '24000000', '9659074', '24474463']
# ['Play it to the Bone', '1999', '24000000', '8427204', '8427204']
# ['Dhoom 3', '2013', '24000000', '8031955', '11723620']
# ['Beyond the Sea', '2004', '24000000', '6144806', '8292914']
# ['Hauru no ugoku shiro', '2005', '24000000', '4710455', '237814327']
# ['Meet the Deedles', '1998', '24000000', '4356126', '4356126']
# ['The Thief and the Cobbler', '1995', '24000000', '669276', '669276']
# ['The Bridge of San Luis Rey', '2005', '24000000', '49981', '1696765']
# ['Flood', None, '24000000', '0', '4084232']
# ['Zombieland', '2009', '23600000', '75590286', '102236596']
# ['Star Wars Ep. V: The Empire Strikes Back', '1980', '23000000', '290271960', '547969004']
# ['The Waterboy', '1998', '23000000', '161491646', '190191646']
# ['The Naked Gun 2½: The Smell of Fear', '1991', '23000000', '86930411', '86930411']
# ['Green Book', '2018', '23000000', '85080171', '319543432']
# ['Bad Boys', '1995', '23000000', '65647413', '141247413']
# ['The Wedding Ringer', '2015', '23000000', '64460211', '80171596']
# ['Final Destination', '2000', '23000000', '53302314', '112036870']
# ['King Kong', '1976', '23000000', '52614445', '90614445']
# ['The Ides of March', '2011', '23000000', '40962534', '77735925']
# ['Pitch Black', '2000', '23000000', '39235088', '53182088']
# ['The Hate U Give', '2018', '23000000', '29719483', '35067665']
# ['Someone Like You', '2001', '23000000', '27338033', '38684906']
# ['Her', '2014', '23000000', '25568251', '48043998']
# ['Joy Ride', '2001', '23000000', '21973182', '22204890']
# ['Kari gurashi no Arietti', '2012', '23000000', '19192510', '151496097']
# ['Haywire', '2012', '23000000', '18942396', '36374700']
# ['Anywhere But Here', '1999', '23000000', '18653615', '18653615']
# ['Vanity Fair', '2004', '23000000', '16123851', '19123851']
# ['Eddie the Eagle', '2016', '23000000', '15789389', '45060480']
# ['Jaws 4: The Revenge', '1987', '23000000', '15728335', '15728335']
# ['The Crew', '2000', '23000000', '13019253', '13019253']
# ["Marvin's Room", '1996', '23000000', '12803305', '12803305']
# ['Chasing Liberty', '2004', '23000000', '12189514', '12291975']
# ['The Longshots', '2008', '23000000', '11511323', '11778396']
# ['The End of the Affair', '1999', '23000000', '10660147', '10660147']
# ['Harley Davidson and the Marlboro Man', '1991', '23000000', '7018525', '7018525']
# ['In the Valley of Elah', '2007', '23000000', '6777741', '24489150']
# ['Coco avant Chanel', '2009', '23000000', '6113834', '50813834']
# ['Chéri', '2009', '23000000', '2715657', '2715657']
# ['Redemption', '2013', '23000000', '36686', '13593473']
# ['Rogue', '2008', '23000000', '10452', '4673377']
# ['Chāi dàn zhuānjiā', '2017', '23000000', '0', '58807172']
# ['Shi Yue Wei Cheng', '2011', '23000000', '0', '44195779']
# ['Spaceballs', '1987', '22700000', '38119483', '38119483']
# ['1408', '2007', '22500000', '71985628', '131263370']
# ['Nocturnal Animals', '2016', '22500000', '10663357', '32398681']
# ['The Water Diviner', '2014', '22500000', '4200117', '31054727']
# ['Ghost', '1990', '22000000', '217631306', '517600000']
# ["There's Something About Mary", '1998', '22000000', '176484651', '369884651']
# ['The Santa Clause', '1994', '22000000', '144833357', '189800000']
# ['The Nun', '2018', '22000000', '117450119', '363676447']
# ['The Game Plan', '2007', '22000000', '90648202', '146590987']
# ['The Rookie', '2002', '22000000', '75600072', '80491516']
# ['The Bridges of Madison County', '1995', '22000000', '71516617', '175516617']
# ['Son of God', '2014', '22000000', '59700064', '70949793']
# ['The Animal', '2001', '22000000', '55762229', '55762229']
# ['The Hundred-Foot Journey', '2014', '22000000', '54235441', '94270488']
# ['Gandhi', '1982', '22000000', '52767889', '127767889']
# ['Underworld', '2003', '22000000', '51970690', '95708457']
# ['The Net', '1995', '22000000', '50621733', '110521733']
# ['Diary of a Wimpy Kid: Dog Days', '2012', '22000000', '49008662', '77229695']
# ['I Am Sam', '2001', '22000000', '40270895', '92542418']

# %%
class Budget:
    def __init__(self, name, date, prod_budget, domestic_gross, worldwide_gross):
        self.name = name
        self.date = date
        self.prod_budget = prod_budget
        self.domestic_gross = domestic_gross
        self.worldwide_gross = worldwide_gross

# %%
def scrape_plot(output_file, path, page_start, page_end):
    failList = []  # collect page that failed
    with open(output_file, 'ab') as output_f:
        for page in range(page_start, page_end, 100):
            print('starting scraping page {}'.format(page))
            url = 'https://www.the-numbers.com/movie/budgets/all/{}'.format(page)
            html = get_HTML_text(page, url, failList, 1, path)
            budgets = get_budget(html)
            for budget in budgets:
                output_f.write('{}\t{}\t{}\t{}\t{}\n'.format(budget.name, budget.date, budget.prod_budget, budget.domestic_gross, budget.worldwide_gross).encode('utf-8'))

# %%
scrape_plot('../../Sample_Data/Raw/budget.tsv', '', 1, 6101)
# Out:
# starting scraping page 1
# starting scraping page 101
# starting scraping page 201
# starting scraping page 301
# starting scraping page 401
# starting scraping page 501
# starting scraping page 601
# starting scraping page 701
# starting scraping page 801
# starting scraping page 901
# starting scraping page 1001
# starting scraping page 1101
# starting scraping page 1201
# starting scraping page 1301
# starting scraping page 1401
# starting scraping page 1501
# starting scraping page 1601
# starting scraping page 1701
# starting scraping page 1801
# starting scraping page 1901
# starting scraping page 2001
# starting scraping page 2101
# starting scraping page 2201
# starting scraping page 2301
# starting scraping page 2401
# starting scraping page 2501
# starting scraping page 2601
# starting scraping page 2701
# starting scraping page 2801
# starting scraping page 2901
# starting scraping page 3001
# starting scraping page 3101
# starting scraping page 3201
# starting scraping page 3301
# starting scraping page 3401
# starting scraping page 3501
# starting scraping page 3601
# starting scraping page 3701
# starting scraping page 3801
# starting scraping page 3901
# starting scraping page 4001
# starting scraping page 4101
# starting scraping page 4201
# starting scraping page 4301
# starting scraping page 4401
# starting scraping page 4501
# starting scraping page 4601
# starting scraping page 4701
# starting scraping page 4801
# starting scraping page 4901
# starting scraping page 5001
# starting scraping page 5101
# starting scraping page 5201
# starting scraping page 5301
# starting scraping page 5401
# starting scraping page 5501
# starting scraping page 5601
# starting scraping page 5701
# starting scraping page 5801
# starting scraping page 5901
# starting scraping page 6001
